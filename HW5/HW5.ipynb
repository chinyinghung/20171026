# %% [markdown]
# # Q1. 寫一個函式，抓取 Google Finance 的股價歷史資料

# %%
import requests

# %%
url = "http://finance.google.com/finance/historical"

# %%
params = {}
params['q'] = 'TSLA'
params['startdate'] = '2016-05-01'
params['output'] = 'csv'

# %%
stockprice = requests.get(url,params = params)

# %%
print (stockprice.text)
# Out:
# Date,Open,High,Low,Close,Volume
# 5-Dec-17,302.00,308.00,301.00,303.70,4646520
# 4-Dec-17,306.50,308.26,300.61,305.20,5835140
# 1-Dec-17,305.44,310.32,305.05,306.53,4292868
# 30-Nov-17,308.56,310.70,304.54,308.85,4351587
# 29-Nov-17,317.30,318.00,301.23,307.54,8767398
# 28-Nov-17,316.36,320.00,313.92,317.55,4949491
# 27-Nov-17,313.25,317.34,309.51,316.81,4555894
# 24-Nov-17,313.79,316.41,311.00,315.55,3244065
# 22-Nov-17,316.77,317.42,311.84,312.60,4917636
# 21-Nov-17,310.86,318.23,308.71,317.81,7261273
# 20-Nov-17,313.79,315.50,304.75,308.74,8247650
# 17-Nov-17,325.67,326.67,313.15,315.05,13735139
# 16-Nov-17,313.99,318.14,311.30,312.50,5822073
# 15-Nov-17,306.01,312.49,301.50,311.30,5978665
# 14-Nov-17,315.00,316.35,306.90,308.70,5676076
# 13-Nov-17,300.13,316.80,299.11,315.40,7584944
# 10-Nov-17,302.50,308.36,301.85,302.99,4625429
# 9-Nov-17,302.50,304.46,296.30,302.99,5447147
# 8-Nov-17,305.50,306.89,301.30,304.39,4725271
# 7-Nov-17,301.02,306.50,300.03,306.05,5294274
# ...

# %% [markdown]
# # Q2. 抓取台股歷史資料，並繪製價量圖形。

# %%
import pandas_datareader.data as web
import kchart
from datetime import datetime

# %%
df = web.DataReader("2330.tw", 'yahoo', datetime(2017,1,1))
df.head()
kchart.draw(df,"2330.tw")
